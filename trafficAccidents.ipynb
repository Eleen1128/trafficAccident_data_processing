# %%
import pandas as pd
import numpy as np

# %%
np.__version__
# Out:
# '1.21.5'

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
#test = pd.read_csv("108taipeiaccidents.csv", encoding="cp950")
#test.dropna().to_csv("108taipeiaccidents.csv")
test = pd.read_csv("108taipeiaccidents.csv")
test
#test.iloc[269]
# Out:
#        Unnamed: 0  發生年  發生月  發生日  發生時  發生分  處理別     區序  \
# 0               0  108    1    2    8   37    2  01大同區
# 1               1  108    1    2    8   37    2  01大同區
# 2               2  108    1    9   10   59    2  01大同區
# 3               3  108    1    9   10   59    2  01大同區
# 4               4  108    1   12   10   10    2  01大同區
# ...           ...  ...  ...  ...  ...  ...  ...    ...
# 50802       52428  108   12   22   17   31    2  07信義區
# 50803       52429  108   12   22   17   31    2  07信義區
# 50804       52430  108   12   22   17   31    2  07信義區
# 50805       52431  108   12   26    7   20    2  07信義區
# 50806       52432  108   12   26    7   20    2  07信義區
#
#                           肇事地點  死亡人數  受傷人數  當事人序   車種  性別    年齡  受傷程度   天候  \
# 0      大同區重慶北路3段137巷與民族西路182巷口     0     2     1  C03   2  37.0   2.0  6.0
# 1      大同區重慶北路3段137巷與民族西路182巷口     0     2     2  C03   2  59.0   2.0  6.0
# 2               大同區重慶北路1段與天水路口     0     1     1  H01   4   0.0   4.0  8.0
# ...

# %%
indexNames = test[(test['性別'] != 1) & (test['性別'] != 2)].index
indexNames
# Out:
# Int64Index([    2,   123,   269,   334,   376,   390,   522,   691,   852,
#               912,
#             ...
#             50423, 50445, 50528, 50579, 50596, 50620, 50730, 50754, 50766,
#             50780],
#            dtype='int64', length=346)

# %%
# Delete these row indexes from dataFrame
test2 = test.drop(indexNames)
test2
# Out:
#        Unnamed: 0  發生年  發生月  發生日  發生時  發生分  處理別     區序  \
# 0               0  108    1    2    8   37    2  01大同區
# 1               1  108    1    2    8   37    2  01大同區
# 3               3  108    1    9   10   59    2  01大同區
# 4               4  108    1   12   10   10    2  01大同區
# 5               5  108    1   12   10   10    2  01大同區
# ...           ...  ...  ...  ...  ...  ...  ...    ...
# 50802       52428  108   12   22   17   31    2  07信義區
# 50803       52429  108   12   22   17   31    2  07信義區
# 50804       52430  108   12   22   17   31    2  07信義區
# 50805       52431  108   12   26    7   20    2  07信義區
# 50806       52432  108   12   26    7   20    2  07信義區
#
#                           肇事地點  死亡人數  受傷人數  當事人序   車種  性別    年齡  受傷程度   天候  \
# 0      大同區重慶北路3段137巷與民族西路182巷口     0     2     1  C03   2  37.0   2.0  6.0
# 1      大同區重慶北路3段137巷與民族西路182巷口     0     2     2  C03   2  59.0   2.0  6.0
# 3               大同區重慶北路1段與天水路口     0     1     2  C03   1  24.0   2.0  8.0
# ...

# %%
test2.to_csv("108taipeiaccidents_gender.csv")

# %%
df = pd.read_csv("108taipeiaccidents_gender.csv")
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  發生年  發生月  發生日  發生時  發生分  處理別     區序  \
# 0                 0           0  108    1    2    8   37    2  01大同區
# 1                 1           1  108    1    2    8   37    2  01大同區
# 2                 3           3  108    1    9   10   59    2  01大同區
# 3                 4           4  108    1   12   10   10    2  01大同區
# 4                 5           5  108    1   12   10   10    2  01大同區
# ...             ...         ...  ...  ...  ...  ...  ...  ...    ...
# 50456         50802       52428  108   12   22   17   31    2  07信義區
# 50457         50803       52429  108   12   22   17   31    2  07信義區
# 50458         50804       52430  108   12   22   17   31    2  07信義區
# 50459         50805       52431  108   12   26    7   20    2  07信義區
# 50460         50806       52432  108   12   26    7   20    2  07信義區
#
#                           肇事地點  ...  受傷人數  當事人序   車種 性別    年齡  受傷程度   天候  速限  \
# ...

# %%
df['車種對照'] = None
df['車種對照'][df['車種'] == "C03"] = "普通重型機車"
df['車種對照'][df['車種'] == "B03"] = "自用小客車"
df['車種對照'][df['車種'] == "H02"] = "乘客"
df['車種對照'][df['車種'] == "B01"] = "計程車"
df['車種對照'][df['車種'] == "H01"] = "行人"
df['車種對照'][df['車種'] == "B12"] = "自用小貨車"
df['車種對照'][df['車種'] == "F01"] = "腳踏自行車"
df['車種對照'][df['車種'] == "B02"] = "租賃小客車"
df['車種對照'][df['車種'] == "A02"] = "民營公車"
df['車種對照'][df['車種'] == "C02"] = "大型重型2(250-550C.C.)"
df['車種對照'][df['車種'] == "B11"] = "營業用小貨車"
df['車種對照'][df['車種'] == "A04"] = "民營客運"
df['車種對照'][df['車種'] == "H03"] = "其他人"
df['車種對照'][df['車種'] == "A12"] = "自用大貨車"
df['車種對照'][df['車種'] == "C01"] = "大型重型1(550C.C.以上)"
df['車種對照'][df['車種'] == "F03"] = "電動自行車"
df['車種對照'][df['車種'] == "A11"] = "營業用大貨車"
df['車種對照'][df['車種'] == "F02"] = "電動輔助自行車"
df['車種對照'][df['車種'] == "A01"] = "公營公車"
df['車種對照'][df['車種'] == "E03"] = "警備車"
df['車種對照'][df['車種'] == "A41"] = "營業用曳引車"
df['車種對照'][df['車種'] == "C05"] = "小型輕型機車"
df['車種對照'][df['車種'] == "G06"] = "其他車"
df['車種對照'][df['車種'] == "E01"] = "救護車"
df['車種對照'][df['車種'] == "G03"] = "動力機械"
df['車種對照'][df['車種'] == "F06"] = "其他慢車"
df['車種對照'][df['車種'] == "E05"] = "其他特種車"
df['車種對照'][df['車種'] == "A03"] = "公營客運"
df['車種對照'][df['車種'] == "G01"] = "拼裝車"
df['車種對照'][df['車種'] == "A42"] = "自用曳引車"
df['車種對照'][df['車種'] == "A31"] = "營業用半聯結車"
df['車種對照'][df['車種'] == "D03"] = "小型車軍車"
df['車種對照'][df['車種'] == "A06"] = "自用大客車"
df['車種對照'][df['車種'] == "F04"] = "人力車"
df['車種對照'][df['車種'] == "E02"] = "消防車"
df['車種對照'][df['車種'] == "C04"] = "普通輕型機車"


df.to_csv("108taipeiaccidents_appendtype.csv")
# Out:
# C:\Users\Eleen\AppData\Local\Temp\ipykernel_3412\1993848946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['車種對照'][df['車種'] == "C03"] = "普通重型機車"
# C:\Users\Eleen\AppData\Local\Temp\ipykernel_3412\1993848946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['車種對照'][df['車種'] == "B03"] = "自用小客車"
# C:\Users\Eleen\AppData\Local\Temp\ipykernel_3412\1993848946.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df = pd.read_csv("108taipeiaccidents_appendtype.csv")

# %%
index_limit = df[(df['速限'] >= 150)].index
index_limit
# Out:
# Int64Index([37986, 37987], dtype='int64')

# %%
df.iloc[37986]
df.iloc[37987]
# Out:
# Unnamed: 0.2          37987
# Unnamed: 0.1          38251
# Unnamed: 0            39386
# 發生年                     108
# 發生月                       9
# 發生日                       2
# 發生時                       7
# 發生分                      16
# 處理別                       2
# 區序                    10文山區
# 肇事地點            文山區育英街與萬慶街口
# 死亡人數                      0
# 受傷人數                      2
# 當事人序                      2
# 車種                      C03
# 性別                        2
# 年齡                     40.0
# 受傷程度                    2.0
# 天候                      8.0
# 速限                      401
# 道路型態                    3.0
# 事故位置                    1.0
# 車種對照                 普通重型機車
# Name: 37987, dtype: object

# %%
 df.loc[37986,['速限']] = [40]
 df.loc[37987,['速限']] = [40]

# %%
df.iloc[37986]
df.iloc[37987]
# Out:
# Unnamed: 0.2          37987
# Unnamed: 0.1          38251
# Unnamed: 0            39386
# 發生年                     108
# 發生月                       9
# 發生日                       2
# 發生時                       7
# 發生分                      16
# 處理別                       2
# 區序                    10文山區
# 肇事地點            文山區育英街與萬慶街口
# 死亡人數                      0
# 受傷人數                      2
# 當事人序                      2
# 車種                      C03
# 性別                        2
# 年齡                     40.0
# 受傷程度                    2.0
# 天候                      8.0
# 速限                       40
# 道路型態                    3.0
# 事故位置                    1.0
# 車種對照                 普通重型機車
# Name: 37987, dtype: object

# %%
df.to_csv("108taipeiaccidents_appendtypelimit.csv")
